# %%
import cv2
import os
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import tensorflow as tf

# class names
class_names = ['၀','၁','၂','၃','၄','၅','၆','၇','၈','၉','အ','ဘ',')','ဒ','ဓ','ဂ','ဟ','ထ','ဌ','က','ခ','လ','မ','န','င','ည','(','ပ','ဖ','ဆ','/','စ','တ','သ','ဥ','ဝ','ရ','ယ','ဇ']

# image folder
folder = 'C:/Users/eaind/ocr/13Sep21Model/cnnpro/data/pa/'

# dimensions of images
img_width, img_height = 224, 224
load_model = tf.keras.models.load_model('savemodel/alexnet_ep30lr0p001bs256m.h5')

# %%
for filename in os.listdir(folder):
    img = cv2.imread(os.path.join(folder,filename))
    if img is not None:
        #plt.imshow(img)
        #plt.show()
        img_resize = cv2.resize(img, (img_width, img_height))
        img_resize_2 = img_resize.reshape(1, 224, 224, 3)
        pred = load_model.predict(img_resize_2)
        cls = class_names[np.argmax(pred)]
        print("Prediction of " + filename + " is  " + cls)
# Out:
# Prediction of pa_0.jpg is  ပ
# Prediction of pa_1.jpg is  ပ
# Prediction of pa_10.jpg is  ပ
# Prediction of pa_100.jpg is  ပ
# Prediction of pa_101.jpg is  ပ
# Prediction of pa_102.jpg is  သ
# Prediction of pa_103.jpg is  လ
# Prediction of pa_104.jpg is  ပ
# Prediction of pa_105.jpg is  သ
# Prediction of pa_106.jpg is  ပ
# Prediction of pa_107.jpg is  ပ
# Prediction of pa_108.jpg is  ပ
# Prediction of pa_109.jpg is  ပ
# Prediction of pa_11.jpg is  ပ
# Prediction of pa_110.jpg is  ပ
# Prediction of pa_111.jpg is  ပ
# Prediction of pa_112.jpg is  ပ
# Prediction of pa_113.jpg is  ပ
# Prediction of pa_114.jpg is  ပ
# Prediction of pa_115.jpg is  ပ
# Prediction of pa_116.jpg is  ပ
# Prediction of pa_117.jpg is  ပ
# Prediction of pa_118.jpg is  မ
# Prediction of pa_119.jpg is  ပ
# Prediction of pa_12.jpg is  ပ
# Prediction of pa_120.jpg is  ပ
# Prediction of pa_121.jpg is  ပ
# Prediction of pa_122.jpg is  မ
# Prediction of pa_123.jpg is  မ
# Prediction of pa_124.jpg is  ၉
# ...
