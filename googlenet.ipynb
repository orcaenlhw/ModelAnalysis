# %%
import tensorflow as tf
from d2l import tensorflow as d2l
import time
import pathlib
data_dir = 'C:/Users/eaind/ocr/13Sep21Model/cnnpro/data/'


class Inception(tf.keras.Model):
    # `c1`--`c4` are the number of output channels for each path
    def __init__(self, c1, c2, c3, c4):
        super().__init__()
        
        self.p1_1 = tf.keras.layers.Conv2D(c1, 1, activation='relu')
        self.p2_1 = tf.keras.layers.Conv2D(c2[0], 1, activation='relu')
        self.p2_2 = tf.keras.layers.Conv2D(c2[1], 3, padding='same',activation='relu')
        self.p3_1 = tf.keras.layers.Conv2D(c3[0], 1, activation='relu')
        self.p3_2 = tf.keras.layers.Conv2D(c3[1], 5, padding='same',activation='relu')
        self.p4_1 = tf.keras.layers.MaxPool2D(3, 1, padding='same')
        self.p4_2 = tf.keras.layers.Conv2D(c4, 1, activation='relu')
        
    def get_config(self):
        cfg = super().get_config()
        return cfg  

    def call(self, x):
        p1 = self.p1_1(x)
        p2 = self.p2_2(self.p2_1(x))
        p3 = self.p3_2(self.p3_1(x))
        p4 = self.p4_2(self.p4_1(x))
        # Concatenate the outputs on the channel dimension
        return tf.keras.layers.Concatenate()([p1, p2, p3, p4])

# %%
def b1():
    return tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(64, 7, strides=2, padding='same',activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')])


def b2():
    return tf.keras.Sequential([
        tf.keras.layers.Conv2D(64, 1, activation='relu'),
        tf.keras.layers.Conv2D(192, 3, padding='same', activation='relu'),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')])


def b3():
    return tf.keras.models.Sequential([
        Inception(64, (96, 128), (16, 32), 32),
        Inception(128, (128, 192), (32, 96), 64),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')])


def b4():
    return tf.keras.Sequential([
        Inception(192, (96, 208), (16, 48), 64),
        Inception(160, (112, 224), (24, 64), 64),
        Inception(128, (128, 256), (24, 64), 64),
        Inception(112, (144, 288), (32, 64), 64),
        Inception(256, (160, 320), (32, 128), 128),
        tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')])


def b5():
    return tf.keras.Sequential([
        Inception(256, (160, 320), (32, 128), 128),
        Inception(384, (192, 384), (48, 128), 128),
        tf.keras.layers.GlobalAvgPool2D(),
        tf.keras.layers.Flatten()
    ])


def net():
    return tf.keras.Sequential([b1(), b2(), b3(), b4(), b5(),
                                tf.keras.layers.Dense(39)])


X = tf.random.uniform(shape=(1, 96, 96, 1))
for layer in net().layers:
    X = layer(X)
    print(layer.__class__.__name__, 'output shape:\t', X.shape)
# Out:
# Sequential output shape:	 (1, 24, 24, 64)
# Sequential output shape:	 (1, 12, 12, 192)
# Sequential output shape:	 (1, 6, 6, 480)
# Sequential output shape:	 (1, 3, 3, 832)
# Sequential output shape:	 (1, 1024)
# Dense output shape:	 (1, 39)

# %%
img_height = 96
img_width = 96
batch_size = 64

train_iter = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
val_iter = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 21897 files belonging to 39 classes.
# Using 17518 files for training.
# Found 21897 files belonging to 39 classes.
# Using 4379 files for validation.

# %%
class TrainCallback(tf.keras.callbacks.Callback):  
    """A callback to visiualize the training progress."""
    def __init__(self, net, train_iter, val_iter, num_epochs, device_name):
        self.timer = d2l.Timer()
        self.animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs], legend=['train loss', 'train acc', 'test acc'])
        self.net = net
        self.train_iter = train_iter
        self.val_iter = val_iter
        self.num_epochs = num_epochs
        self.device_name = device_name
    def on_epoch_begin(self, epoch, logs=None):
        self.timer.start()
    def on_epoch_end(self, epoch, logs):
        if(logs.get('loss')<0.02):
            print("\nReached 98% accuracy so cancelling training!")
            self.net.stop_training = True
        self.timer.stop()
        test_acc = self.net.evaluate(self.val_iter, verbose=0, return_dict=True)['accuracy']
        metrics = (logs['loss'], logs['accuracy'], test_acc)
        self.animator.add(epoch + 1, metrics)
        if epoch == self.num_epochs - 1:
            batch_size = next(iter(self.train_iter))[0].shape[0]
            num_examples = batch_size * tf.data.experimental.cardinality(self.train_iter).numpy()
            print(f'loss {metrics[0]:.3f}, train acc {metrics[1]:.3f}, 'f'test acc {metrics[2]:.3f}')
            print(f'{num_examples / self.timer.avg():.1f} examples/sec on 'f'{str(self.device_name)}')


def train_ch6(net_fn, train_iter, val_iter, num_epochs, lr, device):
    """Train a model with a GPU (defined in Chapter 6)."""
    device_name = device._device_name
    strategy = tf.distribute.OneDeviceStrategy(device_name)
    with strategy.scope():
        optimizer = tf.keras.optimizers.SGD(learning_rate=lr)
        loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        net = net_fn()
        net.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    callback = TrainCallback(net, train_iter, val_iter, num_epochs, device_name)
    net.fit(train_iter, epochs=num_epochs, verbose=0, callbacks=[callback])
    return net

# %%
lr = 0.001
num_epochs = 100
model = train_ch6(net, train_iter, val_iter, num_epochs, lr, d2l.try_gpu())
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (c:\Users\eaind\.vscode\extensions\ms-toolsai.jupyter-2021.8.1054968649\out\client\extension.js:90:320068)
# at w.execute (c:\Users\eaind\.vscode\extensions\ms-toolsai.jupyter-2021.8.1054968649\out\client\extension.js:90:319389)
# at w.start (c:\Users\eaind\.vscode\extensions\ms-toolsai.jupyter-2021.8.1054968649\out\client\extension.js:90:315205)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (c:\Users\eaind\.vscode\extensions\ms-toolsai.jupyter-2021.8.1054968649\out\client\extension.js:90:329732)
# at async t.CellExecutionQueue.start (c:\Users\eaind\.vscode\extensions\ms-toolsai.jupyter-2021.8.1054968649\out\client\extension.js:90:329272)

# %%
model.save('savemodel/ggnet_ep100lr0p001bs64')
# Out:
# INFO:tensorflow:Assets written to: savemodel/ggnet_ep50lr0p001bs64\assets

# %%
loadmodel = tf.keras.models.load_model('savemodel/ggnet_ep30lr0p0001bs128')

loadmodel.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_6 (Sequential)    (None, 24, 24, 64)        9472
# _________________________________________________________________
# sequential_7 (Sequential)    (None, 12, 12, 192)       114944
# _________________________________________________________________
# sequential_8 (Sequential)    (None, 6, 6, 480)         552432
# _________________________________________________________________
# sequential_9 (Sequential)    (None, 3, 3, 832)         2809168
# _________________________________________________________________
# sequential_10 (Sequential)   (None, 1024)              2487536
# _________________________________________________________________
# dense_1 (Dense)              (None, 39)                39975
# =================================================================
# Total params: 6,013,527
# Trainable params: 6,013,527
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss, acc = loadmodel.evaluate(val_iter, verbose=2)
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))

print(loadmodel.predict(val_iter).shape)
# Out:
# 35/35 - 19s - loss: 0.6670 - accuracy: 0.8095
# Restored model, accuracy: 80.95%
# (4379, 39)

# %%
###Testing###

# %%
###Testing###

# %%
###Testing###

# %%
import cv2
import os
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import tensorflow as tf

# class names
class_names = ['၀','၁','၂','၃','၄','၅','၆','၇','၈','၉','အ','ဘ',')','ဒ','ဓ','ဂ','ဟ','ထ','ဌ','က','ခ','လ','မ','န','င','ည','(','ပ','ဖ','ဆ','/','စ','တ','သ','ဥ','ဝ','ရ','ယ','ဇ']

# image folder
folder = 'C:/Users/eaind/ocr/13Sep21Model/cnnpro/data/ka/'

# dimensions of images
img_width, img_height = 96, 96

# %%
for filename in os.listdir(folder):
    img = cv2.imread(os.path.join(folder,filename))
    if img is not None:
        #plt.imshow(img)
        #plt.show()
        img_resize = cv2.resize(img, (img_width, img_height))
        img_resize_2 = img_resize.reshape(1, 96, 96, 3)
        pred = loadmodel.predict(img_resize_2)
        cls = class_names[np.argmax(pred)]
        print("Prediction of " + filename + " is  " + cls)
# Out:
# Prediction of ka_0.jpg is  က
# Prediction of ka_1.jpg is  က
# Prediction of ka_10.jpg is  ဘ
# Prediction of ka_100.jpg is  လ
# Prediction of ka_1000.jpg is  ဘ
# Prediction of ka_1001.jpg is  က
# Prediction of ka_1002.jpg is  က
# Prediction of ka_1003.jpg is  က
# Prediction of ka_1004.jpg is  က
# Prediction of ka_1005.jpg is  က
# Prediction of ka_1006.jpg is  က
# Prediction of ka_1007.jpg is  က
# Prediction of ka_1008.jpg is  လ
# Prediction of ka_1009.jpg is  က
# Prediction of ka_101.jpg is  က
# Prediction of ka_1010.jpg is  က
# Prediction of ka_1011.jpg is  က
# Prediction of ka_1012.jpg is  က
# Prediction of ka_1013.jpg is  လ
# Prediction of ka_1014.jpg is  က
# Prediction of ka_1015.jpg is  က
# Prediction of ka_1016.jpg is  က
# Prediction of ka_1017.jpg is  လ
# Prediction of ka_1018.jpg is  ၇
# Prediction of ka_1019.jpg is  က
# Prediction of ka_102.jpg is  က
# Prediction of ka_1020.jpg is  က
# Prediction of ka_1021.jpg is  က
# Prediction of ka_1022.jpg is  လ
# Prediction of ka_1023.jpg is  က
# Prediction of ka_1024.jpg is  က
# Prediction of ka_1025.jpg is  ၇
# Prediction of ka_1026.jpg is  က
# Prediction of ka_1027.jpg is  က
# Prediction of ka_1028.jpg is  က
# Prediction of ka_1029.jpg is  က
# Prediction of ka_103.jpg is  က
# Prediction of ka_1030.jpg is  က
# Prediction of ka_1031.jpg is  က
# Prediction of ka_1032.jpg is  က
# Prediction of ka_1033.jpg is  က
# Prediction of ka_1034.jpg is  က
# Prediction of ka_1035.jpg is  က
# Prediction of ka_1036.jpg is  လ
# Prediction of ka_1037.jpg is  က
# Prediction of ka_1038.jpg is  က
# Prediction of ka_1039.jpg is  ဘ
# Prediction of ka_104.jpg is  က
# Prediction of ka_1040.jpg is  က
# Prediction of ka_1041.jpg is  က
# Prediction of ka_1042.jpg is  ဘ
# Prediction of ka_1043.jpg is  က
# Prediction of ka_1044.jpg is  က
# Prediction of ka_1045.jpg is  က
# Prediction of ka_1046.jpg is  က
# Prediction of ka_1047.jpg is  က
# Prediction of ka_1048.jpg is  က
# Prediction of ka_1049.jpg is  က
# Prediction of ka_105.jpg is  က
# Prediction of ka_1050.jpg is  က
# Prediction of ka_1051.jpg is  က
# Prediction of ka_1052.jpg is  က
# Prediction of ka_1053.jpg is  က
# Prediction of ka_1054.jpg is  က
# Prediction of ka_1055.jpg is  က
# Prediction of ka_1056.jpg is  က
# Prediction of ka_1057.jpg is  က
# Prediction of ka_1058.jpg is  က
# Prediction of ka_1059.jpg is  က
# Prediction of ka_106.jpg is  က
# Prediction of ka_1060.jpg is  က
# Prediction of ka_1061.jpg is  က
# Prediction of ka_1062.jpg is  က
# Prediction of ka_1063.jpg is  က
# Prediction of ka_1064.jpg is  က
# Prediction of ka_1065.jpg is  က
# Prediction of ka_1066.jpg is  က
# Prediction of ka_1067.jpg is  က
# Prediction of ka_1068.jpg is  က
# Prediction of ka_1069.jpg is  က
# Prediction of ka_107.jpg is  က
# Prediction of ka_1070.jpg is  က
# Prediction of ka_1071.jpg is  က
# Prediction of ka_1072.jpg is  က
# Prediction of ka_1073.jpg is  က
# Prediction of ka_1074.jpg is  က
# Prediction of ka_1075.jpg is  က
# Prediction of ka_1076.jpg is  က
# Prediction of ka_1077.jpg is  က
# Prediction of ka_1078.jpg is  က
# Prediction of ka_1079.jpg is  က
# Prediction of ka_108.jpg is  လ
# Prediction of ka_1080.jpg is  က
# Prediction of ka_1081.jpg is  က
# Prediction of ka_1082.jpg is  က
# Prediction of ka_1083.jpg is  ဘ
# Prediction of ka_1084.jpg is  က
# Prediction of ka_1085.jpg is  က
# Prediction of ka_1086.jpg is  က
# Prediction of ka_1087.jpg is  က
# Prediction of ka_1088.jpg is  က
# Prediction of ka_1089.jpg is  က
# Prediction of ka_109.jpg is  က
# Prediction of ka_1090.jpg is  က
# Prediction of ka_1091.jpg is  က
# Prediction of ka_1092.jpg is  က
# Prediction of ka_1093.jpg is  က
# Prediction of ka_1094.jpg is  လ
# Prediction of ka_1095.jpg is  က
# Prediction of ka_1096.jpg is  က
# Prediction of ka_1097.jpg is  က
# Prediction of ka_1098.jpg is  က
# Prediction of ka_1099.jpg is  က
# Prediction of ka_11.jpg is  က
# Prediction of ka_110.jpg is  က
# Prediction of ka_1100.jpg is  က
# Prediction of ka_1101.jpg is  က
# Prediction of ka_1102.jpg is  က
# Prediction of ka_1103.jpg is  က
# Prediction of ka_1104.jpg is  က
# Prediction of ka_1105.jpg is  က
# Prediction of ka_1106.jpg is  က
# Prediction of ka_1107.jpg is  က
# Prediction of ka_1108.jpg is  က
# Prediction of ka_1109.jpg is  က
# Prediction of ka_111.jpg is  ဆ
# Prediction of ka_1110.jpg is  က
# Prediction of ka_1111.jpg is  က
# Prediction of ka_1112.jpg is  က
# Prediction of ka_1113.jpg is  က
# Prediction of ka_1114.jpg is  က
# Prediction of ka_1115.jpg is  က
# Prediction of ka_1116.jpg is  က
# Prediction of ka_1117.jpg is  က
# Prediction of ka_1118.jpg is  က
# Prediction of ka_1119.jpg is  က
# Prediction of ka_112.jpg is  က
# Prediction of ka_1120.jpg is  လ
# Prediction of ka_1121.jpg is  တ
# Prediction of ka_1122.jpg is  က
# Prediction of ka_1123.jpg is  က
# Prediction of ka_1124.jpg is  ဘ
# Prediction of ka_1125.jpg is  က
# Prediction of ka_1126.jpg is  က
# Prediction of ka_1127.jpg is  က
# Prediction of ka_1128.jpg is  က
# Prediction of ka_1129.jpg is  က
# Prediction of ka_113.jpg is  က
# Prediction of ka_1130.jpg is  က
# Prediction of ka_1131.jpg is  က
# Prediction of ka_1132.jpg is  က
# Prediction of ka_1133.jpg is  က
# Prediction of ka_1134.jpg is  က
# Prediction of ka_1135.jpg is  က
# Prediction of ka_1136.jpg is  က
# Prediction of ka_1137.jpg is  က
# Prediction of ka_1138.jpg is  က
# Prediction of ka_1139.jpg is  က
# Prediction of ka_114.jpg is  က
# Prediction of ka_1140.jpg is  က
# Prediction of ka_1141.jpg is  က
# Prediction of ka_1142.jpg is  က
# Prediction of ka_1143.jpg is  က
# Prediction of ka_1144.jpg is  က
# Prediction of ka_1145.jpg is  က
# Prediction of ka_1146.jpg is  က
# Prediction of ka_1147.jpg is  က
# Prediction of ka_1148.jpg is  က
# Prediction of ka_1149.jpg is  က
# Prediction of ka_115.jpg is  က
# Prediction of ka_1150.jpg is  က
# Prediction of ka_1151.jpg is  က
# Prediction of ka_1152.jpg is  က
# Prediction of ka_1153.jpg is  က
# Prediction of ka_1154.jpg is  က
# Prediction of ka_1155.jpg is  က
# Prediction of ka_1156.jpg is  က
# Prediction of ka_1157.jpg is  က
# Prediction of ka_1158.jpg is  က
# Prediction of ka_1159.jpg is  က
# Prediction of ka_116.jpg is  က
# Prediction of ka_1160.jpg is  က
# Prediction of ka_1161.jpg is  က
# Prediction of ka_1162.jpg is  က
# Prediction of ka_1163.jpg is  က
# Prediction of ka_1164.jpg is  က
# Prediction of ka_1165.jpg is  က
# Prediction of ka_1166.jpg is  က
# Prediction of ka_1167.jpg is  က
# Prediction of ka_1168.jpg is  က
# Prediction of ka_1169.jpg is  က
# Prediction of ka_117.jpg is  က
# Prediction of ka_1170.jpg is  က
# Prediction of ka_1171.jpg is  က
# Prediction of ka_1172.jpg is  က
# Prediction of ka_1173.jpg is  က
# Prediction of ka_1174.jpg is  က
# Prediction of ka_1175.jpg is  က
# Prediction of ka_1176.jpg is  က
# Prediction of ka_1177.jpg is  က
# Prediction of ka_1178.jpg is  လ
# Prediction of ka_1179.jpg is  က
# Prediction of ka_118.jpg is  က
# Prediction of ka_1180.jpg is  လ
# Prediction of ka_1181.jpg is  က
# Prediction of ka_1182.jpg is  က
# Prediction of ka_1183.jpg is  က
# Prediction of ka_1184.jpg is  က
# Prediction of ka_1185.jpg is  က
# Prediction of ka_1186.jpg is  ဘ
# Prediction of ka_1187.jpg is  လ
# Prediction of ka_1188.jpg is  က
# Prediction of ka_1189.jpg is  က
# Prediction of ka_119.jpg is  က
# Prediction of ka_1190.jpg is  က
# Prediction of ka_1191.jpg is  က
# Prediction of ka_1192.jpg is  က
# Prediction of ka_1193.jpg is  စ
# Prediction of ka_1194.jpg is  က
# Prediction of ka_1195.jpg is  လ
# Prediction of ka_1196.jpg is  က
# Prediction of ka_1197.jpg is  က
# Prediction of ka_1198.jpg is  က
# Prediction of ka_1199.jpg is  က
# Prediction of ka_12.jpg is  ဘ
# Prediction of ka_120.jpg is  က
# Prediction of ka_1200.jpg is  က
# Prediction of ka_1201.jpg is  က
# Prediction of ka_1202.jpg is  ဘ
# Prediction of ka_1203.jpg is  က
# Prediction of ka_1204.jpg is  က
# Prediction of ka_1205.jpg is  က
# Prediction of ka_1206.jpg is  က
# Prediction of ka_1207.jpg is  က
# Prediction of ka_1208.jpg is  က
# Prediction of ka_1209.jpg is  က
# Prediction of ka_121.jpg is  က
# Prediction of ka_1210.jpg is  က
# Prediction of ka_1211.jpg is  က
# Prediction of ka_1212.jpg is  ၇
# Prediction of ka_1213.jpg is  က
# Prediction of ka_1214.jpg is  က
# Prediction of ka_1215.jpg is  က
# Prediction of ka_1216.jpg is  က
# Prediction of ka_1217.jpg is  က
# Prediction of ka_1218.jpg is  က
# Prediction of ka_1219.jpg is  က
# Prediction of ka_122.jpg is  ဘ
# Prediction of ka_1220.jpg is  က
# Prediction of ka_1221.jpg is  က
# Prediction of ka_1222.jpg is  က
# Prediction of ka_1223.jpg is  က
# Prediction of ka_1224.jpg is  က
# Prediction of ka_1225.jpg is  က
# Prediction of ka_1226.jpg is  လ
# Prediction of ka_1227.jpg is  က
# Prediction of ka_1228.jpg is  က
# Prediction of ka_1229.jpg is  က
# Prediction of ka_123.jpg is  က
# Prediction of ka_1230.jpg is  က
# Prediction of ka_1231.jpg is  က
# Prediction of ka_1232.jpg is  က
# Prediction of ka_1233.jpg is  က
# Prediction of ka_1234.jpg is  က
# Prediction of ka_1235.jpg is  လ
# Prediction of ka_124.jpg is  က
# Prediction of ka_125.jpg is  က
# Prediction of ka_126.jpg is  က
# Prediction of ka_127.jpg is  က
# Prediction of ka_128.jpg is  က
# Prediction of ka_129.jpg is  က
# Prediction of ka_13.jpg is  က
# Prediction of ka_130.jpg is  က
# Prediction of ka_131.jpg is  က
# Prediction of ka_132.jpg is  က
# Prediction of ka_133.jpg is  က
# Prediction of ka_134.jpg is  က
# Prediction of ka_135.jpg is  က
# Prediction of ka_136.jpg is  က
# Prediction of ka_137.jpg is  က
# Prediction of ka_138.jpg is  က
# Prediction of ka_139.jpg is  က
# Prediction of ka_14.jpg is  က
# Prediction of ka_140.jpg is  က
# Prediction of ka_141.jpg is  က
# Prediction of ka_142.jpg is  က
# Prediction of ka_143.jpg is  က
# Prediction of ka_144.jpg is  ဘ
# Prediction of ka_145.jpg is  က
# Prediction of ka_146.jpg is  က
# Prediction of ka_147.jpg is  က
# Prediction of ka_148.jpg is  က
# Prediction of ka_149.jpg is  က
# Prediction of ka_15.jpg is  က
# Prediction of ka_150.jpg is  က
# Prediction of ka_151.jpg is  က
# Prediction of ka_152.jpg is  က
# Prediction of ka_153.jpg is  က
# Prediction of ka_154.jpg is  က
# Prediction of ka_155.jpg is  က
# Prediction of ka_156.jpg is  ဘ
# Prediction of ka_157.jpg is  က
# Prediction of ka_158.jpg is  က
# Prediction of ka_159.jpg is  က
# Prediction of ka_16.jpg is  က
# Prediction of ka_160.jpg is  လ
# Prediction of ka_161.jpg is  က
# Prediction of ka_162.jpg is  က
# Prediction of ka_163.jpg is  က
# Prediction of ka_164.jpg is  က
# Prediction of ka_165.jpg is  က
# Prediction of ka_166.jpg is  သ
# Prediction of ka_167.jpg is  က
# Prediction of ka_168.jpg is  က
# Prediction of ka_169.jpg is  က
# Prediction of ka_17.jpg is  က
# Prediction of ka_170.jpg is  က
# Prediction of ka_171.jpg is  က
# Prediction of ka_172.jpg is  က
# Prediction of ka_173.jpg is  က
# Prediction of ka_174.jpg is  က
# Prediction of ka_175.jpg is  က
# Prediction of ka_176.jpg is  က
# Prediction of ka_177.jpg is  က
# Prediction of ka_178.jpg is  က
# Prediction of ka_179.jpg is  က
# Prediction of ka_18.jpg is  က
# Prediction of ka_180.jpg is  က
# Prediction of ka_181.jpg is  က
# Prediction of ka_182.jpg is  က
# Prediction of ka_183.jpg is  က
# Prediction of ka_184.jpg is  က
# Prediction of ka_185.jpg is  ဘ
# Prediction of ka_186.jpg is  က
# Prediction of ka_187.jpg is  က
# Prediction of ka_188.jpg is  က
# Prediction of ka_189.jpg is  က
# Prediction of ka_19.jpg is  က
# Prediction of ka_190.jpg is  က
# Prediction of ka_191.jpg is  က
# Prediction of ka_192.jpg is  က
# Prediction of ka_193.jpg is  က
# Prediction of ka_194.jpg is  က
# Prediction of ka_195.jpg is  က
# Prediction of ka_196.jpg is  က
# Prediction of ka_197.jpg is  က
# Prediction of ka_198.jpg is  က
# Prediction of ka_199.jpg is  က
# Prediction of ka_2.jpg is  က
# Prediction of ka_20.jpg is  က
# Prediction of ka_200.jpg is  က
# Prediction of ka_201.jpg is  က
# Prediction of ka_202.jpg is  ဘ
# Prediction of ka_203.jpg is  က
# Prediction of ka_204.jpg is  က
# Prediction of ka_205.jpg is  က
# Prediction of ka_206.jpg is  သ
# Prediction of ka_207.jpg is  က
# Prediction of ka_208.jpg is  က
# Prediction of ka_209.jpg is  က
# Prediction of ka_21.jpg is  က
# Prediction of ka_210.jpg is  က
# Prediction of ka_211.jpg is  က
# Prediction of ka_212.jpg is  က
# Prediction of ka_213.jpg is  က
# Prediction of ka_214.jpg is  က
# Prediction of ka_215.jpg is  က
# Prediction of ka_216.jpg is  က
# Prediction of ka_217.jpg is  က
# Prediction of ka_218.jpg is  ဘ
# Prediction of ka_219.jpg is  က
# Prediction of ka_22.jpg is  က
# Prediction of ka_220.jpg is  က
# Prediction of ka_221.jpg is  က
# Prediction of ka_222.jpg is  က
# Prediction of ka_223.jpg is  က
# Prediction of ka_224.jpg is  က
# Prediction of ka_225.jpg is  က
# Prediction of ka_226.jpg is  တ
# Prediction of ka_227.jpg is  က
# Prediction of ka_228.jpg is  က
# Prediction of ka_229.jpg is  က
# Prediction of ka_23.jpg is  က
# Prediction of ka_230.jpg is  က
# Prediction of ka_231.jpg is  က
# Prediction of ka_232.jpg is  က
# Prediction of ka_233.jpg is  က
# Prediction of ka_234.jpg is  က
# Prediction of ka_235.jpg is  က
# Prediction of ka_236.jpg is  က
# Prediction of ka_237.jpg is  က
# Prediction of ka_238.jpg is  က
# Prediction of ka_239.jpg is  က
# Prediction of ka_24.jpg is  က
# Prediction of ka_240.jpg is  က
# Prediction of ka_241.jpg is  က
# Prediction of ka_242.jpg is  က
# Prediction of ka_243.jpg is  ထ
# Prediction of ka_244.jpg is  က
# Prediction of ka_245.jpg is  က
# Prediction of ka_246.jpg is  က
# Prediction of ka_247.jpg is  က
# Prediction of ka_248.jpg is  က
# Prediction of ka_249.jpg is  က
# Prediction of ka_25.jpg is  က
# Prediction of ka_250.jpg is  က
# Prediction of ka_251.jpg is  က
# Prediction of ka_252.jpg is  က
# Prediction of ka_253.jpg is  က
# Prediction of ka_254.jpg is  က
# Prediction of ka_255.jpg is  က
# Prediction of ka_256.jpg is  က
# Prediction of ka_257.jpg is  က
# Prediction of ka_258.jpg is  က
# Prediction of ka_259.jpg is  က
# Prediction of ka_26.jpg is  က
# Prediction of ka_260.jpg is  က
# Prediction of ka_261.jpg is  က
# Prediction of ka_262.jpg is  က
# Prediction of ka_263.jpg is  က
# Prediction of ka_264.jpg is  က
# Prediction of ka_265.jpg is  က
# Prediction of ka_266.jpg is  က
# Prediction of ka_267.jpg is  က
# Prediction of ka_268.jpg is  က
# Prediction of ka_269.jpg is  က
# Prediction of ka_27.jpg is  က
# Prediction of ka_270.jpg is  က
# Prediction of ka_271.jpg is  က
# Prediction of ka_272.jpg is  က
# Prediction of ka_273.jpg is  က
# Prediction of ka_274.jpg is  က
# Prediction of ka_275.jpg is  က
# Prediction of ka_276.jpg is  က
# Prediction of ka_277.jpg is  က
# Prediction of ka_278.jpg is  က
# Prediction of ka_279.jpg is  က
# Prediction of ka_28.jpg is  လ
# Prediction of ka_280.jpg is  က
# Prediction of ka_281.jpg is  က
# Prediction of ka_282.jpg is  တ
# Prediction of ka_283.jpg is  က
# Prediction of ka_284.jpg is  က
# Prediction of ka_285.jpg is  က
# Prediction of ka_286.jpg is  က
# Prediction of ka_287.jpg is  က
# Prediction of ka_288.jpg is  က
# Prediction of ka_289.jpg is  က
# Prediction of ka_29.jpg is  က
# Prediction of ka_290.jpg is  က
# Prediction of ka_291.jpg is  က
# Prediction of ka_292.jpg is  က
# Prediction of ka_293.jpg is  က
# Prediction of ka_294.jpg is  က
# Prediction of ka_295.jpg is  က
# Prediction of ka_296.jpg is  က
# Prediction of ka_297.jpg is  က
# Prediction of ka_298.jpg is  က
# Prediction of ka_299.jpg is  က
# Prediction of ka_3.jpg is  က
# Prediction of ka_30.jpg is  က
# Prediction of ka_300.jpg is  က
# Prediction of ka_301.jpg is  က
# Prediction of ka_302.jpg is  က
# Prediction of ka_303.jpg is  က
# Prediction of ka_304.jpg is  က
# Prediction of ka_305.jpg is  က
# Prediction of ka_306.jpg is  က
# Prediction of ka_307.jpg is  က
# Prediction of ka_308.jpg is  က
# Prediction of ka_309.jpg is  က
# Prediction of ka_31.jpg is  က
# Prediction of ka_310.jpg is  က
# Prediction of ka_311.jpg is  က
# Prediction of ka_312.jpg is  က
# Prediction of ka_313.jpg is  ဘ
# Prediction of ka_314.jpg is  က
# Prediction of ka_315.jpg is  က
# Prediction of ka_316.jpg is  က
# Prediction of ka_317.jpg is  က
# Prediction of ka_318.jpg is  က
# Prediction of ka_319.jpg is  က
# Prediction of ka_32.jpg is  က
# Prediction of ka_320.jpg is  က
# Prediction of ka_321.jpg is  က
# Prediction of ka_322.jpg is  က
# Prediction of ka_323.jpg is  က
# Prediction of ka_324.jpg is  က
# Prediction of ka_325.jpg is  က
# Prediction of ka_326.jpg is  က
# Prediction of ka_327.jpg is  က
# Prediction of ka_328.jpg is  က
# Prediction of ka_329.jpg is  က
# Prediction of ka_33.jpg is  က
# Prediction of ka_330.jpg is  က
# Prediction of ka_331.jpg is  က
# Prediction of ka_332.jpg is  က
# Prediction of ka_333.jpg is  လ
# Prediction of ka_334.jpg is  က
# Prediction of ka_335.jpg is  က
# Prediction of ka_336.jpg is  က
# Prediction of ka_337.jpg is  က
# Prediction of ka_338.jpg is  က
# Prediction of ka_339.jpg is  က
# Prediction of ka_34.jpg is  က
# Prediction of ka_340.jpg is  က
# Prediction of ka_341.jpg is  က
# Prediction of ka_342.jpg is  က
# Prediction of ka_343.jpg is  က
# Prediction of ka_344.jpg is  က
# Prediction of ka_345.jpg is  က
# Prediction of ka_346.jpg is  က
# Prediction of ka_347.jpg is  က
# Prediction of ka_348.jpg is  က
# Prediction of ka_349.jpg is  လ
# Prediction of ka_35.jpg is  က
# Prediction of ka_350.jpg is  က
# Prediction of ka_351.jpg is  က
# Prediction of ka_352.jpg is  က
# Prediction of ka_353.jpg is  က
# Prediction of ka_354.jpg is  န
# Prediction of ka_355.jpg is  က
# Prediction of ka_356.jpg is  က
# Prediction of ka_357.jpg is  က
# Prediction of ka_358.jpg is  က
# Prediction of ka_359.jpg is  က
# Prediction of ka_36.jpg is  က
# Prediction of ka_360.jpg is  က
# Prediction of ka_361.jpg is  က
# Prediction of ka_362.jpg is  က
# Prediction of ka_363.jpg is  က
# Prediction of ka_364.jpg is  လ
# Prediction of ka_365.jpg is  က
# Prediction of ka_366.jpg is  က
# Prediction of ka_367.jpg is  က
# Prediction of ka_368.jpg is  က
# Prediction of ka_369.jpg is  က
# Prediction of ka_37.jpg is  က
# Prediction of ka_370.jpg is  က
# Prediction of ka_371.jpg is  က
# Prediction of ka_372.jpg is  က
# Prediction of ka_373.jpg is  က
# Prediction of ka_374.jpg is  က
# Prediction of ka_375.jpg is  က
# Prediction of ka_376.jpg is  က
# Prediction of ka_377.jpg is  က
# Prediction of ka_378.jpg is  က
# Prediction of ka_379.jpg is  က
# Prediction of ka_38.jpg is  က
# Prediction of ka_380.jpg is  က
# Prediction of ka_381.jpg is  က
# Prediction of ka_382.jpg is  က
# Prediction of ka_383.jpg is  က
# Prediction of ka_384.jpg is  က
# Prediction of ka_385.jpg is  က
# Prediction of ka_386.jpg is  က
# Prediction of ka_387.jpg is  လ
# Prediction of ka_388.jpg is  က
# Prediction of ka_389.jpg is  က
# Prediction of ka_39.jpg is  က
# Prediction of ka_390.jpg is  က
# Prediction of ka_391.jpg is  က
# Prediction of ka_392.jpg is  က
# Prediction of ka_393.jpg is  က
# Prediction of ka_394.jpg is  က
# Prediction of ka_395.jpg is  က
# Prediction of ka_396.jpg is  က
# Prediction of ka_397.jpg is  က
# Prediction of ka_398.jpg is  က
# Prediction of ka_399.jpg is  က
# Prediction of ka_4.jpg is  က
# Prediction of ka_40.jpg is  က
# Prediction of ka_400.jpg is  က
# Prediction of ka_401.jpg is  က
# Prediction of ka_402.jpg is  က
# Prediction of ka_403.jpg is  က
# Prediction of ka_404.jpg is  က
# Prediction of ka_405.jpg is  က
# Prediction of ka_406.jpg is  က
# Prediction of ka_407.jpg is  က
# Prediction of ka_408.jpg is  က
# Prediction of ka_409.jpg is  က
# Prediction of ka_41.jpg is  က
# Prediction of ka_410.jpg is  က
# Prediction of ka_411.jpg is  က
# Prediction of ka_412.jpg is  က
# Prediction of ka_413.jpg is  က
# Prediction of ka_414.jpg is  က
# Prediction of ka_415.jpg is  က
# Prediction of ka_416.jpg is  က
# Prediction of ka_417.jpg is  က
# Prediction of ka_418.jpg is  က
# Prediction of ka_419.jpg is  က
# Prediction of ka_42.jpg is  က
# Prediction of ka_420.jpg is  က
# Prediction of ka_421.jpg is  သ
# Prediction of ka_422.jpg is  က
# Prediction of ka_423.jpg is  ဘ
# Prediction of ka_424.jpg is  လ
# Prediction of ka_425.jpg is  က
# Prediction of ka_426.jpg is  လ
# Prediction of ka_427.jpg is  က
# Prediction of ka_428.jpg is  က
# Prediction of ka_429.jpg is  က
# Prediction of ka_43.jpg is  က
# Prediction of ka_430.jpg is  က
# Prediction of ka_431.jpg is  က
# Prediction of ka_432.jpg is  က
# Prediction of ka_433.jpg is  က
# Prediction of ka_434.jpg is  က
# Prediction of ka_435.jpg is  က
# Prediction of ka_436.jpg is  က
# Prediction of ka_437.jpg is  က
# Prediction of ka_438.jpg is  က
# Prediction of ka_439.jpg is  က
# Prediction of ka_44.jpg is  က
# Prediction of ka_440.jpg is  က
# Prediction of ka_441.jpg is  လ
# Prediction of ka_442.jpg is  က
# Prediction of ka_443.jpg is  က
# Prediction of ka_444.jpg is  က
# Prediction of ka_445.jpg is  က
# Prediction of ka_446.jpg is  က
# Prediction of ka_447.jpg is  က
# Prediction of ka_448.jpg is  က
# Prediction of ka_449.jpg is  က
# Prediction of ka_45.jpg is  က
# Prediction of ka_450.jpg is  လ
# Prediction of ka_451.jpg is  က
# Prediction of ka_452.jpg is  က
# Prediction of ka_453.jpg is  က
# Prediction of ka_454.jpg is  က
# Prediction of ka_455.jpg is  က
# Prediction of ka_456.jpg is  က
# Prediction of ka_457.jpg is  ၅
# Prediction of ka_458.jpg is  တ
# Prediction of ka_459.jpg is  က
# Prediction of ka_46.jpg is  က
# Prediction of ka_460.jpg is  က
# Prediction of ka_461.jpg is  က
# Prediction of ka_462.jpg is  က
# Prediction of ka_463.jpg is  တ
# Prediction of ka_464.jpg is  က
# Prediction of ka_465.jpg is  က
# Prediction of ka_466.jpg is  က
# Prediction of ka_467.jpg is  ဘ
# Prediction of ka_468.jpg is  က
# Prediction of ka_469.jpg is  က
# Prediction of ka_47.jpg is  က
# Prediction of ka_470.jpg is  က
# Prediction of ka_471.jpg is  က
# Prediction of ka_472.jpg is  က
# Prediction of ka_473.jpg is  က
# Prediction of ka_474.jpg is  က
# Prediction of ka_475.jpg is  က
# Prediction of ka_476.jpg is  က
# Prediction of ka_477.jpg is  က
# Prediction of ka_478.jpg is  လ
# Prediction of ka_479.jpg is  က
# Prediction of ka_48.jpg is  က
# Prediction of ka_480.jpg is  လ
# Prediction of ka_481.jpg is  က
# Prediction of ka_482.jpg is  က
# Prediction of ka_483.jpg is  က
# Prediction of ka_484.jpg is  က
# Prediction of ka_485.jpg is  က
# Prediction of ka_486.jpg is  က
# Prediction of ka_487.jpg is  က
# Prediction of ka_488.jpg is  က
# Prediction of ka_489.jpg is  က
# Prediction of ka_49.jpg is  န
# Prediction of ka_490.jpg is  က
# Prediction of ka_491.jpg is  က
# Prediction of ka_492.jpg is  က
# Prediction of ka_493.jpg is  က
# Prediction of ka_494.jpg is  က
# Prediction of ka_495.jpg is  က
# Prediction of ka_496.jpg is  က
# Prediction of ka_497.jpg is  က
# Prediction of ka_498.jpg is  က
# Prediction of ka_499.jpg is  က
# Prediction of ka_5.jpg is  က
# Prediction of ka_50.jpg is  က
# Prediction of ka_500.jpg is  က
# Prediction of ka_501.jpg is  က
# Prediction of ka_502.jpg is  က
# Prediction of ka_503.jpg is  က
# Prediction of ka_504.jpg is  က
# Prediction of ka_505.jpg is  က
# Prediction of ka_506.jpg is  က
# Prediction of ka_507.jpg is  က
# Prediction of ka_508.jpg is  က
# Prediction of ka_509.jpg is  လ
# Prediction of ka_51.jpg is  က
# Prediction of ka_510.jpg is  က
# Prediction of ka_511.jpg is  က
# Prediction of ka_512.jpg is  က
# Prediction of ka_513.jpg is  က
# Prediction of ka_514.jpg is  က
# Prediction of ka_515.jpg is  က
# Prediction of ka_516.jpg is  က
# Prediction of ka_517.jpg is  က
# Prediction of ka_518.jpg is  က
# Prediction of ka_519.jpg is  က
# Prediction of ka_52.jpg is  က
# Prediction of ka_520.jpg is  က
# Prediction of ka_521.jpg is  က
# Prediction of ka_522.jpg is  က
# Prediction of ka_523.jpg is  က
# Prediction of ka_524.jpg is  က
# Prediction of ka_525.jpg is  က
# Prediction of ka_526.jpg is  က
# Prediction of ka_527.jpg is  က
# Prediction of ka_528.jpg is  က
# Prediction of ka_529.jpg is  က
# Prediction of ka_53.jpg is  လ
# Prediction of ka_530.jpg is  က
# Prediction of ka_531.jpg is  က
# Prediction of ka_532.jpg is  က
# Prediction of ka_533.jpg is  က
# Prediction of ka_534.jpg is  က
# Prediction of ka_535.jpg is  ဘ
# Prediction of ka_536.jpg is  က
# Prediction of ka_537.jpg is  က
# Prediction of ka_538.jpg is  က
# Prediction of ka_539.jpg is  က
# Prediction of ka_54.jpg is  က
# Prediction of ka_540.jpg is  က
# Prediction of ka_541.jpg is  က
# Prediction of ka_542.jpg is  က
# Prediction of ka_543.jpg is  က
# Prediction of ka_544.jpg is  က
# Prediction of ka_545.jpg is  က
# Prediction of ka_546.jpg is  က
# Prediction of ka_547.jpg is  က
# Prediction of ka_548.jpg is  က
# Prediction of ka_549.jpg is  က
# Prediction of ka_55.jpg is  က
# Prediction of ka_550.jpg is  က
# Prediction of ka_551.jpg is  က
# Prediction of ka_552.jpg is  က
# Prediction of ka_553.jpg is  က
# Prediction of ka_554.jpg is  က
# Prediction of ka_555.jpg is  က
# Prediction of ka_556.jpg is  က
# Prediction of ka_557.jpg is  လ
# Prediction of ka_558.jpg is  က
# Prediction of ka_559.jpg is  က
# Prediction of ka_56.jpg is  က
# Prediction of ka_560.jpg is  က
# Prediction of ka_561.jpg is  က
# Prediction of ka_562.jpg is  က
# Prediction of ka_563.jpg is  က
# Prediction of ka_564.jpg is  က
# Prediction of ka_565.jpg is  က
# Prediction of ka_566.jpg is  က
# Prediction of ka_567.jpg is  က
# Prediction of ka_568.jpg is  က
# Prediction of ka_569.jpg is  က
# Prediction of ka_57.jpg is  က
# Prediction of ka_570.jpg is  လ
# Prediction of ka_571.jpg is  က
# Prediction of ka_572.jpg is  က
# Prediction of ka_573.jpg is  က
# Prediction of ka_574.jpg is  က
# Prediction of ka_575.jpg is  က
# Prediction of ka_576.jpg is  က
# Prediction of ka_577.jpg is  က
# Prediction of ka_578.jpg is  က
# Prediction of ka_579.jpg is  က
# Prediction of ka_58.jpg is  က
# Prediction of ka_580.jpg is  ၅
# Prediction of ka_581.jpg is  က
# Prediction of ka_582.jpg is  က
# Prediction of ka_583.jpg is  က
# Prediction of ka_584.jpg is  က
# Prediction of ka_585.jpg is  သ
# Prediction of ka_586.jpg is  လ
# Prediction of ka_587.jpg is  က
# Prediction of ka_588.jpg is  က
# Prediction of ka_589.jpg is  က
# Prediction of ka_59.jpg is  က
# Prediction of ka_590.jpg is  က
# Prediction of ka_591.jpg is  က
# Prediction of ka_592.jpg is  က
# Prediction of ka_593.jpg is  က
# Prediction of ka_594.jpg is  က
# Prediction of ka_595.jpg is  လ
# Prediction of ka_596.jpg is  က
# Prediction of ka_597.jpg is  က
# Prediction of ka_598.jpg is  လ
# Prediction of ka_599.jpg is  က
# Prediction of ka_6.jpg is  တ
# Prediction of ka_60.jpg is  က
# Prediction of ka_600.jpg is  က
# Prediction of ka_601.jpg is  ဆ
# Prediction of ka_602.jpg is  ဘ
# Prediction of ka_603.jpg is  က
# Prediction of ka_604.jpg is  က
# Prediction of ka_605.jpg is  က
# Prediction of ka_606.jpg is  က
# Prediction of ka_607.jpg is  က
# Prediction of ka_608.jpg is  က
# Prediction of ka_609.jpg is  က
# Prediction of ka_61.jpg is  က
# Prediction of ka_610.jpg is  က
# Prediction of ka_611.jpg is  က
# Prediction of ka_612.jpg is  က
# Prediction of ka_613.jpg is  လ
# Prediction of ka_614.jpg is  က
# Prediction of ka_615.jpg is  က
# Prediction of ka_616.jpg is  က
# Prediction of ka_617.jpg is  က
# Prediction of ka_618.jpg is  က
# Prediction of ka_619.jpg is  ဆ
# Prediction of ka_62.jpg is  က
# Prediction of ka_620.jpg is  က
# Prediction of ka_621.jpg is  က
# Prediction of ka_622.jpg is  က
# Prediction of ka_623.jpg is  က
# Prediction of ka_624.jpg is  က
# Prediction of ka_625.jpg is  လ
# Prediction of ka_626.jpg is  က
# Prediction of ka_627.jpg is  က
# Prediction of ka_628.jpg is  က
# Prediction of ka_629.jpg is  က
# Prediction of ka_63.jpg is  က
# Prediction of ka_630.jpg is  က
# Prediction of ka_631.jpg is  က
# Prediction of ka_632.jpg is  က
# Prediction of ka_633.jpg is  က
# Prediction of ka_634.jpg is  က
# Prediction of ka_635.jpg is  က
# Prediction of ka_636.jpg is  က
# Prediction of ka_637.jpg is  လ
# Prediction of ka_638.jpg is  က
# Prediction of ka_639.jpg is  က
# Prediction of ka_64.jpg is  က
# Prediction of ka_640.jpg is  က
# Prediction of ka_641.jpg is  က
# Prediction of ka_642.jpg is  က
# Prediction of ka_643.jpg is  က
# Prediction of ka_644.jpg is  က
# Prediction of ka_645.jpg is  က
# Prediction of ka_646.jpg is  က
# Prediction of ka_647.jpg is  က
# Prediction of ka_648.jpg is  လ
# Prediction of ka_649.jpg is  က
# Prediction of ka_65.jpg is  က
# Prediction of ka_650.jpg is  က
# Prediction of ka_651.jpg is  က
# Prediction of ka_652.jpg is  က
# Prediction of ka_653.jpg is  က
# Prediction of ka_654.jpg is  က
# Prediction of ka_655.jpg is  လ
# Prediction of ka_656.jpg is  က
# Prediction of ka_657.jpg is  က
# Prediction of ka_658.jpg is  က
# Prediction of ka_659.jpg is  က
# Prediction of ka_66.jpg is  က
# Prediction of ka_660.jpg is  က
# Prediction of ka_661.jpg is  က
# Prediction of ka_662.jpg is  လ
# Prediction of ka_663.jpg is  က
# Prediction of ka_664.jpg is  က
# Prediction of ka_665.jpg is  က
# Prediction of ka_666.jpg is  က
# Prediction of ka_667.jpg is  က
# Prediction of ka_668.jpg is  က
# Prediction of ka_669.jpg is  က
# Prediction of ka_67.jpg is  က
# Prediction of ka_670.jpg is  က
# Prediction of ka_671.jpg is  က
# Prediction of ka_672.jpg is  က
# Prediction of ka_673.jpg is  က
# Prediction of ka_674.jpg is  က
# Prediction of ka_675.jpg is  က
# Prediction of ka_676.jpg is  က
# Prediction of ka_677.jpg is  က
# Prediction of ka_678.jpg is  က
# Prediction of ka_679.jpg is  က
# Prediction of ka_68.jpg is  က
# Prediction of ka_680.jpg is  က
# Prediction of ka_681.jpg is  က
# Prediction of ka_682.jpg is  က
# Prediction of ka_683.jpg is  က
# Prediction of ka_684.jpg is  က
# Prediction of ka_685.jpg is  က
# Prediction of ka_686.jpg is  က
# Prediction of ka_687.jpg is  က
# Prediction of ka_688.jpg is  က
# Prediction of ka_689.jpg is  က
# Prediction of ka_69.jpg is  က
# Prediction of ka_690.jpg is  က
# Prediction of ka_691.jpg is  က
# Prediction of ka_692.jpg is  က
# Prediction of ka_693.jpg is  က
# Prediction of ka_694.jpg is  က
# Prediction of ka_695.jpg is  က
# Prediction of ka_696.jpg is  က
# Prediction of ka_697.jpg is  က
# Prediction of ka_698.jpg is  က
# Prediction of ka_699.jpg is  က
# Prediction of ka_7.jpg is  လ
# Prediction of ka_70.jpg is  က
# Prediction of ka_700.jpg is  က
# Prediction of ka_701.jpg is  က
# Prediction of ka_702.jpg is  က
# Prediction of ka_703.jpg is  က
# Prediction of ka_704.jpg is  က
# Prediction of ka_705.jpg is  က
# Prediction of ka_706.jpg is  က
# Prediction of ka_707.jpg is  သ
# Prediction of ka_708.jpg is  က
# Prediction of ka_709.jpg is  က
# Prediction of ka_71.jpg is  က
# Prediction of ka_710.jpg is  က
# Prediction of ka_711.jpg is  က
# Prediction of ka_712.jpg is  က
# Prediction of ka_713.jpg is  က
# Prediction of ka_714.jpg is  က
# Prediction of ka_715.jpg is  က
# Prediction of ka_716.jpg is  က
# Prediction of ka_717.jpg is  က
# Prediction of ka_718.jpg is  က
# Prediction of ka_719.jpg is  က
# Prediction of ka_72.jpg is  က
# Prediction of ka_720.jpg is  က
# Prediction of ka_721.jpg is  က
# Prediction of ka_722.jpg is  က
# Prediction of ka_723.jpg is  က
# Prediction of ka_724.jpg is  က
# Prediction of ka_725.jpg is  က
# Prediction of ka_726.jpg is  က
# Prediction of ka_727.jpg is  က
# Prediction of ka_728.jpg is  က
# Prediction of ka_729.jpg is  က
# Prediction of ka_73.jpg is  က
# Prediction of ka_730.jpg is  က
# Prediction of ka_731.jpg is  က
# Prediction of ka_732.jpg is  ဘ
# Prediction of ka_733.jpg is  က
# Prediction of ka_734.jpg is  က
# Prediction of ka_735.jpg is  က
# Prediction of ka_736.jpg is  က
# Prediction of ka_737.jpg is  က
# Prediction of ka_738.jpg is  က
# Prediction of ka_739.jpg is  က
# Prediction of ka_74.jpg is  က
# Prediction of ka_740.jpg is  က
# Prediction of ka_741.jpg is  က
# Prediction of ka_742.jpg is  က
# Prediction of ka_743.jpg is  က
# Prediction of ka_744.jpg is  က
# Prediction of ka_745.jpg is  က
# Prediction of ka_746.jpg is  က
# Prediction of ka_747.jpg is  က
# Prediction of ka_748.jpg is  က
# Prediction of ka_749.jpg is  က
# Prediction of ka_75.jpg is  က
# Prediction of ka_750.jpg is  က
# Prediction of ka_751.jpg is  ဘ
# Prediction of ka_752.jpg is  က
# Prediction of ka_753.jpg is  ဘ
# Prediction of ka_754.jpg is  က
# Prediction of ka_755.jpg is  က
# Prediction of ka_756.jpg is  က
# Prediction of ka_757.jpg is  က
# Prediction of ka_758.jpg is  က
# Prediction of ka_759.jpg is  ဘ
# Prediction of ka_76.jpg is  က
# Prediction of ka_760.jpg is  က
# Prediction of ka_761.jpg is  ဆ
# Prediction of ka_762.jpg is  က
# Prediction of ka_763.jpg is  က
# Prediction of ka_764.jpg is  လ
# Prediction of ka_765.jpg is  က
# Prediction of ka_766.jpg is  က
# Prediction of ka_767.jpg is  လ
# Prediction of ka_768.jpg is  ဘ
# Prediction of ka_769.jpg is  က
# Prediction of ka_77.jpg is  က
# Prediction of ka_770.jpg is  က
# Prediction of ka_771.jpg is  ၅
# Prediction of ka_772.jpg is  က
# Prediction of ka_773.jpg is  ဘ
# Prediction of ka_774.jpg is  က
# Prediction of ka_775.jpg is  က
# Prediction of ka_776.jpg is  လ
# Prediction of ka_777.jpg is  က
# Prediction of ka_778.jpg is  က
# Prediction of ka_779.jpg is  က
# Prediction of ka_78.jpg is  က
# Prediction of ka_780.jpg is  က
# Prediction of ka_781.jpg is  က
# Prediction of ka_782.jpg is  က
# Prediction of ka_783.jpg is  လ
# Prediction of ka_784.jpg is  က
# Prediction of ka_785.jpg is  ရ
# Prediction of ka_786.jpg is  က
# Prediction of ka_787.jpg is  က
# Prediction of ka_788.jpg is  က
# Prediction of ka_789.jpg is  က
# Prediction of ka_79.jpg is  က
# Prediction of ka_790.jpg is  က
# Prediction of ka_791.jpg is  က
# Prediction of ka_792.jpg is  က
# Prediction of ka_793.jpg is  က
# Prediction of ka_794.jpg is  က
# Prediction of ka_795.jpg is  က
# Prediction of ka_796.jpg is  လ
# Prediction of ka_797.jpg is  က
# Prediction of ka_798.jpg is  က
# Prediction of ka_799.jpg is  က
# Prediction of ka_8.jpg is  က
# Prediction of ka_80.jpg is  က
# Prediction of ka_800.jpg is  က
# Prediction of ka_801.jpg is  က
# Prediction of ka_802.jpg is  က
# Prediction of ka_803.jpg is  က
# Prediction of ka_804.jpg is  က
# Prediction of ka_805.jpg is  က
# Prediction of ka_806.jpg is  က
# Prediction of ka_807.jpg is  က
# Prediction of ka_808.jpg is  က
# Prediction of ka_809.jpg is  က
# Prediction of ka_81.jpg is  က
# Prediction of ka_810.jpg is  က
# Prediction of ka_811.jpg is  က
# Prediction of ka_812.jpg is  က
# Prediction of ka_813.jpg is  က
# Prediction of ka_814.jpg is  က
# Prediction of ka_815.jpg is  က
# Prediction of ka_816.jpg is  က
# Prediction of ka_817.jpg is  က
# Prediction of ka_818.jpg is  က
# Prediction of ka_819.jpg is  က
# Prediction of ka_82.jpg is  က
# Prediction of ka_820.jpg is  က
# Prediction of ka_821.jpg is  က
# Prediction of ka_822.jpg is  က
# Prediction of ka_823.jpg is  က
# Prediction of ka_824.jpg is  က
# Prediction of ka_825.jpg is  က
# Prediction of ka_826.jpg is  က
# Prediction of ka_827.jpg is  က
# Prediction of ka_828.jpg is  က
# Prediction of ka_829.jpg is  က
# Prediction of ka_83.jpg is  က
# Prediction of ka_830.jpg is  က
# Prediction of ka_831.jpg is  က
# Prediction of ka_832.jpg is  က
# Prediction of ka_833.jpg is  က
# Prediction of ka_834.jpg is  က
# Prediction of ka_835.jpg is  က
# Prediction of ka_836.jpg is  ၇
# Prediction of ka_837.jpg is  က
# Prediction of ka_838.jpg is  က
# Prediction of ka_839.jpg is  က
# Prediction of ka_84.jpg is  က
# Prediction of ka_840.jpg is  က
# Prediction of ka_841.jpg is  က
# Prediction of ka_842.jpg is  က
# Prediction of ka_843.jpg is  က
# Prediction of ka_844.jpg is  က
# Prediction of ka_845.jpg is  က
# Prediction of ka_846.jpg is  က
# Prediction of ka_847.jpg is  က
# Prediction of ka_848.jpg is  က
# Prediction of ka_849.jpg is  က
# Prediction of ka_85.jpg is  က
# Prediction of ka_850.jpg is  က
# Prediction of ka_851.jpg is  က
# Prediction of ka_852.jpg is  က
# Prediction of ka_853.jpg is  က
# Prediction of ka_854.jpg is  က
# Prediction of ka_855.jpg is  က
# Prediction of ka_856.jpg is  က
# Prediction of ka_857.jpg is  က
# Prediction of ka_858.jpg is  က
# Prediction of ka_859.jpg is  က
# Prediction of ka_86.jpg is  လ
# Prediction of ka_860.jpg is  က
# Prediction of ka_861.jpg is  က
# Prediction of ka_862.jpg is  က
# Prediction of ka_863.jpg is  က
# Prediction of ka_864.jpg is  က
# Prediction of ka_865.jpg is  က
# Prediction of ka_866.jpg is  က
# Prediction of ka_867.jpg is  က
# Prediction of ka_868.jpg is  က
# Prediction of ka_869.jpg is  က
# Prediction of ka_87.jpg is  က
# Prediction of ka_870.jpg is  က
# Prediction of ka_871.jpg is  က
# Prediction of ka_872.jpg is  က
# Prediction of ka_873.jpg is  ဘ
# Prediction of ka_874.jpg is  က
# Prediction of ka_875.jpg is  က
# Prediction of ka_876.jpg is  က
# Prediction of ka_877.jpg is  က
# Prediction of ka_878.jpg is  က
# Prediction of ka_879.jpg is  က
# Prediction of ka_88.jpg is  သ
# Prediction of ka_880.jpg is  က
# Prediction of ka_881.jpg is  စ
# Prediction of ka_882.jpg is  က
# Prediction of ka_883.jpg is  က
# Prediction of ka_884.jpg is  က
# Prediction of ka_885.jpg is  က
# Prediction of ka_886.jpg is  က
# Prediction of ka_887.jpg is  က
# Prediction of ka_888.jpg is  က
# Prediction of ka_889.jpg is  က
# Prediction of ka_89.jpg is  က
# Prediction of ka_890.jpg is  ဘ
# Prediction of ka_891.jpg is  က
# Prediction of ka_892.jpg is  က
# Prediction of ka_893.jpg is  က
# Prediction of ka_894.jpg is  က
# Prediction of ka_895.jpg is  က
# Prediction of ka_896.jpg is  က
# Prediction of ka_897.jpg is  က
# Prediction of ka_898.jpg is  လ
# Prediction of ka_899.jpg is  က
# Prediction of ka_9.jpg is  က
# Prediction of ka_90.jpg is  က
# Prediction of ka_900.jpg is  က
# Prediction of ka_901.jpg is  က
# Prediction of ka_902.jpg is  က
# Prediction of ka_903.jpg is  က
# Prediction of ka_904.jpg is  က
# Prediction of ka_905.jpg is  က
# Prediction of ka_906.jpg is  က
# Prediction of ka_907.jpg is  က
# Prediction of ka_908.jpg is  က
# Prediction of ka_909.jpg is  က
# Prediction of ka_91.jpg is  က
# Prediction of ka_910.jpg is  က
# Prediction of ka_911.jpg is  က
# Prediction of ka_912.jpg is  က
# Prediction of ka_913.jpg is  က
# Prediction of ka_914.jpg is  က
# Prediction of ka_915.jpg is  လ
# Prediction of ka_916.jpg is  က
# Prediction of ka_917.jpg is  က
# Prediction of ka_918.jpg is  က
# Prediction of ka_919.jpg is  က
# Prediction of ka_92.jpg is  က
# Prediction of ka_920.jpg is  က
# Prediction of ka_921.jpg is  က
# Prediction of ka_922.jpg is  က
# Prediction of ka_923.jpg is  က
# Prediction of ka_924.jpg is  လ
# Prediction of ka_925.jpg is  က
# Prediction of ka_926.jpg is  က
# Prediction of ka_927.jpg is  က
# Prediction of ka_928.jpg is  က
# Prediction of ka_929.jpg is  က
# Prediction of ka_93.jpg is  ရ
# Prediction of ka_930.jpg is  က
# Prediction of ka_931.jpg is  က
# Prediction of ka_932.jpg is  က
# Prediction of ka_933.jpg is  က
# Prediction of ka_934.jpg is  က
# Prediction of ka_935.jpg is  က
# Prediction of ka_936.jpg is  က
# Prediction of ka_937.jpg is  က
# Prediction of ka_938.jpg is  က
# Prediction of ka_939.jpg is  က
# Prediction of ka_94.jpg is  က
# Prediction of ka_940.jpg is  န
# Prediction of ka_941.jpg is  က
# Prediction of ka_942.jpg is  က
# Prediction of ka_943.jpg is  က
# Prediction of ka_944.jpg is  လ
# Prediction of ka_945.jpg is  က
# Prediction of ka_946.jpg is  က
# Prediction of ka_947.jpg is  က
# Prediction of ka_948.jpg is  က
# Prediction of ka_949.jpg is  က
# Prediction of ka_95.jpg is  က
# Prediction of ka_950.jpg is  က
# Prediction of ka_951.jpg is  က
# Prediction of ka_952.jpg is  က
# Prediction of ka_953.jpg is  က
# Prediction of ka_954.jpg is  က
# Prediction of ka_955.jpg is  က
# Prediction of ka_956.jpg is  က
# Prediction of ka_957.jpg is  က
# Prediction of ka_958.jpg is  က
# Prediction of ka_959.jpg is  က
# Prediction of ka_96.jpg is  က
# Prediction of ka_960.jpg is  က
# Prediction of ka_961.jpg is  က
# Prediction of ka_962.jpg is  က
# Prediction of ka_963.jpg is  က
# Prediction of ka_964.jpg is  က
# Prediction of ka_965.jpg is  က
# Prediction of ka_966.jpg is  က
# Prediction of ka_967.jpg is  က
# Prediction of ka_968.jpg is  စ
# Prediction of ka_969.jpg is  က
# Prediction of ka_97.jpg is  က
# Prediction of ka_970.jpg is  က
# Prediction of ka_971.jpg is  က
# Prediction of ka_972.jpg is  က
# Prediction of ka_973.jpg is  ဘ
# Prediction of ka_974.jpg is  က
# Prediction of ka_975.jpg is  က
# Prediction of ka_976.jpg is  က
# Prediction of ka_977.jpg is  က
# Prediction of ka_978.jpg is  က
# Prediction of ka_979.jpg is  က
# Prediction of ka_98.jpg is  က
# Prediction of ka_980.jpg is  က
# Prediction of ka_981.jpg is  က
# Prediction of ka_982.jpg is  က
# Prediction of ka_983.jpg is  က
# Prediction of ka_984.jpg is  က
# Prediction of ka_985.jpg is  က
# Prediction of ka_986.jpg is  က
# Prediction of ka_987.jpg is  က
# Prediction of ka_988.jpg is  က
# Prediction of ka_989.jpg is  က
# Prediction of ka_99.jpg is  က
# Prediction of ka_990.jpg is  က
# Prediction of ka_991.jpg is  က
# Prediction of ka_992.jpg is  က
# Prediction of ka_993.jpg is  ဘ
# Prediction of ka_994.jpg is  က
# Prediction of ka_995.jpg is  က
# Prediction of ka_996.jpg is  က
# Prediction of ka_997.jpg is  က
# Prediction of ka_998.jpg is  က
# Prediction of ka_999.jpg is  က
